# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv("spam.csv", encoding='latin-1')
df = df[['v1', 'v2']]
df.columns = ['label', 'message']
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['label_num'] = df['label'].map({'ham': 0, 'spam': 1})
print("Null values:\n", df.isnull().sum())
# Out:
# Null values:
#  label        0
# message      0
# label_num    0
# dtype: int64

# %%
sns.countplot(data=df, x='label')
plt.title("Count of Ham vs Spam Messages")
plt.show()

# %%
X = df['message']
y = df['label_num']
cv = CountVectorizer()
X_cv = cv.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_cv, y, test_size=0.2, random_state=42)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)
print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.97847533632287
# Confusion Matrix:
#  [[952  13]
#  [ 11 139]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       965
#            1       0.91      0.93      0.92       150
#
#     accuracy                           0.98      1115
#    macro avg       0.95      0.96      0.95      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
def predict_email(text):
    text_vector = cv.transform([text])
    prediction = model.predict(text_vector)
    return "Spam" if prediction[0] == 1 else "Not Spam"
print(predict_email("Congratulations! You've won a free iPhone. Click to claim."))
print(predict_email("Hi, let's meet at 3 PM today."))
# Out:
# Spam
# Not Spam

# %%
df['length'] = df['message'].apply(len)
plt.figure(figsize=(10,6))
df[df['label']=='ham']['length'].plot.hist(bins=50, label='Ham', alpha=0.7)
df[df['label']=='spam']['length'].plot.hist(bins=50, label='Spam', alpha=0.7, color='red')
plt.legend()
plt.title("✉️ Email Length Distribution (Ham vs Spam)")
plt.xlabel("Length of Email")
plt.show()

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
spam_words = ' '.join(df[df['label']=='spam']['message'])
ham_words = ' '.join(df[df['label']=='ham']['message'])
spam_wc = WordCloud(width=600, height=400, background_color='black').generate(spam_words)
plt.figure(figsize=(10,6))
plt.imshow(spam_wc, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud - Spam Emails")
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Ham', 'Spam'], yticklabels=['Ham', 'Spam'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(" Confusion Matrix")
plt.show()
# Out:
# C:\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['length'] = df['message'].apply(len)
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(4,6))
sns.violinplot(x='label', y='length', data=df, palette='Set2')
plt.title(" Message Length Distribution (Spam vs Ham)")
plt.xlabel("Label")
plt.ylabel("Length of Message")
plt.show()
# Out:
# C:\Users\poongodi\AppData\Local\Temp\ipykernel_2628\1036077401.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='label', y='length', data=df, palette='Set2')

# %%
from collections import Counter
import string
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
def preprocess(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    return [word for word in text.split() if word not in stop_words]
spam_words = df[df['label'] == 'spam']['message'].apply(preprocess).sum()
spam_counts = Counter(spam_words).most_common(20)
words_spam, freq_spam = zip(*spam_counts)
plt.figure(figsize=(6,5))
sns.barplot(x=list(freq_spam), y=list(words_spam), palette='rocket')
plt.title("Top 20 Most Common Words in Spam Emails")
plt.xlabel("Frequency")
plt.ylabel("Words")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\poongodi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\poongodi\AppData\Local\Temp\ipykernel_2628\1647631431.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(freq_spam), y=list(words_spam), palette='rocket')

# %%
ham_words = df[df['label'] == 'ham']['message'].apply(preprocess).sum()
ham_counts = Counter(ham_words).most_common(20)
words_ham, freq_ham = zip(*ham_counts)
plt.figure(figsize=(6,5))
sns.barplot(x=list(freq_ham), y=list(words_ham), palette='crest')
plt.title("Top 20 Most Common Words in Ham Emails")
plt.xlabel("Frequency")
plt.ylabel("Words")
plt.show()
# Out:
# C:\Users\poongodi\AppData\Local\Temp\ipykernel_2628\2935548681.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(freq_ham), y=list(words_ham), palette='crest')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
tfidf = TfidfVectorizer(stop_words='english')
X_tfidf = tfidf.fit_transform(df['message'])
y = df['label_num']
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)
model = MultinomialNB()
model.fit(X_train, y_train)
feature_names = tfidf.get_feature_names_out()
spam_feature_log_prob = model.feature_log_prob_[1]  
top_spam_indices = np.argsort(spam_feature_log_prob)[-20:]
top_spam_words = feature_names[top_spam_indices]
top_spam_probs = spam_feature_log_prob[top_spam_indices]
plt.figure(figsize=(5,4))
plt.barh(top_spam_words, top_spam_probs, color='crimson')
plt.xlabel("Log Probability")
plt.title(" Top 20 Words Indicative of Spam (TF-IDF + Naive Bayes)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\poongodi\AppData\Local\Temp\ipykernel_2628\641207173.py:35: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
total = len(df)
spam = df['label'].value_counts()['spam']
ham = df['label'].value_counts()['ham']
print(f"Total Messages: {total}")
print(f"Spam Messages: {spam} ({round(spam/total*100, 2)}%)")
print(f"Ham Messages: {ham} ({round(ham/total*100, 2)}%)")
# Out:
# Total Messages: 5572
# Spam Messages: 747 (13.41%)
# Ham Messages: 4825 (86.59%)

# %%
avg_spam_len = df[df['label'] == 'spam']['length'].mean()
avg_ham_len = df[df['label'] == 'ham']['length'].mean()
print(f" Average Spam Message Length: {round(avg_spam_len, 2)} characters")
print(f" Average Ham Message Length: {round(avg_ham_len, 2)} characters")
# Out:
#  Average Spam Message Length: 138.87 characters
#  Average Ham Message Length: 71.02 characters

# %%
shortest_msg = df.loc[df['length'].idxmin()]
print("Shortest Message:")
print(shortest_msg['message'], "\n")
longest_msg = df.loc[df['length'].idxmax()]
print("Longest Message:")
print(longest_msg['message'])
# Out:
# Shortest Message:
# Ok
#
# Longest Message:
# For me the love should start with attraction.i should feel that I need her every time around me.she should be the first thing which comes in my thoughts.I would start the day and end it with her.she should be there every time I dream.love will be then when my every breath has her name.my life should happen around her.my life will be named to her.I would cry for her.will give all my happiness and take all her sorrows.I will be ready to fight with anyone for her.I will be in love when I will be doing the craziest things for her.love will be when I don't have to proove anyone that my girl is the most beautiful lady on the whole planet.I will always be singing praises for her.love will be when I start up making chicken curry and end up makiing sambar.life will be the most beautiful then.will get every morning and thank god for the day because she is with me.I would like to say a lot..will tell later..

# %%
first_words = df[df['label'] == 'spam']['message'].apply(lambda x: x.split()[0].lower() if len(x.split()) > 0 else '')
top_first_words = pd.Series(first_words).value_counts().head(10)
plt.figure(figsize=(8,5))
sns.barplot(x=top_first_words.values, y=top_first_words.index, palette='flare')
plt.title("Top 10 Starting Words in Spam Emails")
plt.xlabel("Frequency")
plt.ylabel("First Word")
plt.show()
# Out:
# C:\Users\poongodi\AppData\Local\Temp\ipykernel_2628\2709171933.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_first_words.values, y=top_first_words.index, palette='flare')
# C:\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129512 (\N{FIRECRACKER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
